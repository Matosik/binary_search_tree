# %%
import matplotlib.pyplot  as plt 
import pandas as pd

# %%
fill= pd.Series({1000:0.000480346, 10000:0.00496328,100000:0.0482626})
plt.plot(fill)
plt.title("Заполнение")
plt.show()

# %%
search= pd.Series({1000:0.0000001088, 10000:0.0000002181,100000:0.0000003874})
plt.title("Поиск")
plt.plot(search)
plt.show()

# %%
addition= pd.Series({1000:0.0000002479 , 10000:0.0000002921,100000:0.0000004887})
plt.plot(addition)
plt.title("Добавление")
plt.show()

# %%
deleting= pd.Series({1000:1.091000e-07 , 10000:1.957000e-07,100000:4.044000e-07})
plt.plot(deleting)
plt.title("Удаление")
plt.show()
